# %% [markdown]
# <a href="https://colab.research.google.com/github/aishu29sep/C/blob/main/anemiafalciforme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CBC data_for_meandeley_csv.csv')
df.head()
# Out:
#    S. No.  Age        Sex                 RBC                     PCV  \
# 0     NaN        NaN    NaN  Red Blood Cell count  Packed Cell Volume
# 1     1.0       28.0    0.0                  5.66                  34
# 2     2.0       41.0    0.0                  4.78                44.5
# 3     3.0       40.0    1.0                  4.65                41.6
# 4     4.0       76.0    0.0                  4.24                36.7
#
#               MCV                     MCH   MCHC    \
# 0  Mean Cell Volume  Mean Cell Hemoglobin      NaN
# 1              60.1                    17     28.2
# 2              93.1                  28.9     31.0
# 3              89.5                  28.8     32.2
# 4              86.6                  26.7     30.8
#
#                        RDW                                TLC  PLT /mm3  \
# 0  Red Cell Distribution width  White Blood Cell (WBC count),  Platelet
# 1                           20                           11.1     128.3
# ...

# %%
df.columns
# Out:
# Index(['S. No.', 'Age      ', 'Sex  ', '  RBC    ', 'PCV', 'MCV  ', 'MCH',
#        ' MCHC  ', ' RDW    ', 'TLC', ' PLT /mm3', ' HGB '],
#       dtype='object')

# %%
df.dtypes
# Out:
# S. No.       float64
# Age          float64
# Sex          float64
#   RBC         object
# PCV           object
# MCV           object
# MCH           object
#  MCHC        float64
#  RDW          object
# TLC           object
#  PLT /mm3     object
#  HGB          object
# dtype: object

# %%
df.drop(0, axis=0, inplace=True)
df.head()
# Out:
#    S. No.  Age        Sex     RBC       PCV MCV     MCH   MCHC    RDW      \
# 1     1.0       28.0    0.0      5.66    34  60.1    17     28.2       20
# 2     2.0       41.0    0.0      4.78  44.5  93.1  28.9     31.0       13
# 3     3.0       40.0    1.0      4.65  41.6  89.5  28.8     32.2       13
# 4     4.0       76.0    0.0      4.24  36.7  86.6  26.7     30.8     14.9
# 5     5.0       20.0    1.0      4.14  36.9  89.1  27.8     31.2     13.2
#
#      TLC  PLT /mm3  HGB
# 1   11.1     128.3   9.6
# 2   7.02       419  13.8
# 3   8.09       325  13.4
# 4  13.41       264  11.3
# 5   4.75       196  11.5

# %%
df = df.astype('float64')

# %%
df.dropna(axis=0, inplace=True)

# %%
df.tail()
# Out:
#      S. No.  Age        Sex     RBC      PCV MCV    MCH   MCHC    RDW      \
# 369     NaN        NaN    NaN       NaN  NaN   NaN  NaN      NaN      NaN
# 370     NaN        NaN    NaN       NaN  NaN   NaN  NaN      NaN      NaN
# 371     NaN        NaN    NaN       NaN  NaN   NaN  NaN      NaN      NaN
# 372     NaN        NaN    NaN       NaN  NaN   NaN  NaN      NaN      NaN
# 373     NaN        NaN    NaN       NaN  NaN   NaN  NaN      NaN      NaN
#
#      TLC  PLT /mm3  HGB
# 369  NaN       NaN   NaN
# 370  NaN       NaN   NaN
# 371  NaN       NaN   NaN
# 372  NaN       NaN   NaN
# 373  NaN       NaN   NaN

# %%
df.dtypes
# Out:
# S. No.       float64
# Age          float64
# Sex          float64
#   RBC        float64
# PCV          float64
# MCV          float64
# MCH          float64
#  MCHC        float64
#  RDW         float64
# TLC          float64
#  PLT /mm3    float64
#  HGB         float64
# dtype: object

# %%
df.corr()
# Out:
#              S. No.  Age           Sex      RBC           PCV     MCV    \
# S. No.     1.000000   0.051263  0.120786  -0.025623 -0.016503 -0.000988
# Age        0.051263   1.000000 -0.096953  -0.121013 -0.091488  0.029824
# Sex        0.120786  -0.096953  1.000000  -0.223250 -0.285619 -0.150611
#   RBC     -0.025623  -0.121013 -0.223250   1.000000  0.791414 -0.346350
# PCV       -0.016503  -0.091488 -0.285619   0.791414  1.000000  0.160614
# MCV       -0.000988   0.029824 -0.150611  -0.346350  0.160614  1.000000
# MCH        0.157555   0.055131 -0.229228  -0.405315 -0.018626  0.774251
#  MCHC      0.204934   0.092982 -0.200581  -0.195765 -0.209509  0.052354
#  RDW      -0.127601  -0.014405  0.138318  -0.233634 -0.312195 -0.019982
# TLC        0.027507   0.232505  0.022214   0.070206  0.059052 -0.079189
#  PLT /mm3  0.032725  -0.018868  0.117968   0.039208 -0.030149 -0.122880
#  HGB       0.095855  -0.089315 -0.373981   0.746524  0.853293  0.179613
#
# ...

# %%
sns.heatmap(df.corr(), cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='  RBC    ', y=' HGB ', data=df)
# Out:
# <AxesSubplot:xlabel='  RBC    ', ylabel=' HGB '>

# %%
sns.regplot(x='PCV', y=' HGB ', data=df)
# Out:
# <AxesSubplot:xlabel='PCV', ylabel=' HGB '>
